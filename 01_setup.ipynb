# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import os, json

# Klasörler oluştur
base = '/content/drive/MyDrive/KemikAI'
for k in ['data/raw', 'data/processed', 'data/synthetic',
          'notebooks', 'models/checkpoints', 'models/final',
          'outputs/plots', 'outputs/gradcam', 'outputs/reports',
          'src', 'app']:
    os.makedirs(f'{base}/{k}', exist_ok=True)

print("✅ Klasörler hazır!")
print(os.listdir('/content/drive/MyDrive'))
# Out:
# Mounted at /content/drive
# ✅ Klasörler hazır!
# ...

# %%
import os, json

# Kaggle API kur
os.makedirs('/root/.kaggle', exist_ok=True)
with open('/root/.kaggle/kaggle.json', 'w') as f:
    json.dump({"username": "senaglkara", "key": "KGAT_b293084b61aef1864b5a42096b003c6a"}, f)
os.chmod('/root/.kaggle/kaggle.json', 0o600)

os.system('pip install kaggle -q')

# Veri setini direkt Drive'a indir
base = '/content/drive/MyDrive/KemikAI'
os.system(f'kaggle datasets download -d ipythonx/rsna-bone-age -p {base}/data/raw/')

print("✅ İndirme tamamlandı!")
# Out:
# ✅ İndirme tamamlandı!

# %%
import zipfile, os

base = '/content/drive/MyDrive/KemikAI'
zip_path = f'{base}/data/raw/rsna-bone-age.zip'

print("Açılıyor... (5-10 dk sürebilir)")
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(f'{base}/data/raw/')

print("✅ Veri seti hazır!")
print(os.listdir(f'{base}/data/raw/'))
# Out:
# Açılıyor... (5-10 dk sürebilir)
# ✅ Veri seti hazır!
# ['rsna-bone-age.zip', 'RSNA_Annotations', 'RSNA_test', 'RSNA_train', 'RSNA_val']
